# %%
# ============================================
# CART Regression on Two Different Datasets
# ============================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_diabetes, fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


# --------------------------------------------
# Function to Train & Evaluate CART Model
# --------------------------------------------
def evaluate_regression_model(dataset_loader, dataset_name, is_fetch=False):
    print(f"\n{'='*60}")
    print(f"Dataset: {dataset_name}")
    print(f"{'='*60}")

    # Load dataset
    if is_fetch:
        data = dataset_loader()
    else:
        data = dataset_loader()

    X = data.data
    y = data.target

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, random_state=42)

    # CART Regressor (MSE based)
    model = DecisionTreeRegressor(
        criterion="squared_error",
        random_state=42
    )
    model.fit(X_train, y_train)

    # Predictions
    y_pred = model.predict(X_test)

    # Metrics
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    print("MSE  :", mse)
    print("RMSE :", rmse)
    print("MAE  :", mae)
    print("R2   :", r2)

    print("Tree Depth:", model.get_depth())
    print("No. of Leaves:", model.get_n_leaves())

    return model, data


# --------------------------------------------
# 1️⃣ Diabetes Dataset
# --------------------------------------------
diabetes_model, diabetes_data = evaluate_regression_model(
    load_diabetes,
    "Diabetes Dataset"
)

# Predicting new sample
new_sample = [diabetes_data.data[0]]
prediction = diabetes_model.predict(new_sample)
print("New Diabetes Sample Prediction:", prediction[0])


# --------------------------------------------
# 2️⃣ California Housing Dataset
# --------------------------------------------
housing_model, housing_data = evaluate_regression_model(
    fetch_california_housing,
    "California Housing Dataset",
    is_fetch=True
)

# Predicting new sample
new_sample = [housing_data.data[0]]
prediction = housing_model.predict(new_sample)
print("New Housing Price Prediction:", prediction[0])
# Out:
# ...
# Dataset: Diabetes Dataset
# ...
# MSE  : 5697.789473684211
# RMSE : 75.48370336492647
# MAE  : 60.015037593984964
# R2   : -0.05547696148647652
# Tree Depth: 17
# No. of Leaves: 303
# New Diabetes Sample Prediction: 293.0
#
# ...
# Dataset: California Housing Dataset
# ...
# MSE  : 0.5280096503174904
# RMSE : 0.7266427253592307
# MAE  : 0.46904822189922485
# R2   : 0.5977192261218356
# Tree Depth: 34
# No. of Leaves: 13833
# New Housing Price Prediction: 5.000010000000002
